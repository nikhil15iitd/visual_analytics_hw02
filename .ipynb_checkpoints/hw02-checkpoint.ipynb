# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, show, output_notebook
from bokeh.io import push_notebook
from ipywidgets import interact, fixed
from collections import OrderedDict
from math import log, sqrt
from bokeh.layouts import column, row, widgetbox
from bokeh.models import HoverTool, ColumnDataSource, Select, CustomJS
output_notebook()

TOOLS="crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,"

data = pd.read_csv('Wholesale customers data-missing.csv')
columns = data.columns
# approach 1: ignore row with missing value
data1 = data.dropna(axis=0)
# approach 2: fill missing value with 1
data2 = data.fillna(1)
# approach 3: fill it with mean value
mean = data.mean(axis=0)
data3 = data.fillna(mean)

region_color = OrderedDict([
    ("Lisbon",   "#0d3362"),
    ("Oporto", "#c64737"),
    ("Other Region",     "black"  ),
])

dwarf_constant = 10
width = 700
height = 700
inner_radius = 90
outer_radius = 300 - 10
delta = outer_radius - inner_radius

minr = sqrt(log(0.01*1E4))
maxr = sqrt(log(2000 * 1E4))
a = delta / (minr - maxr)
b = inner_radius - a * maxr

def rad(mic, max_vals):
    return inner_radius + (delta*mic/max_vals)

def circle_renderer(df, categorical_column, columns_to_drop):
    new_df = df.drop(columns_to_drop, axis=1)
    grouped = new_df.groupby(categorical_column)
    new_df = grouped.aggregate('mean')
    big_angle = 2.0 * np.pi / (len(new_df.columns))
    small_angle = big_angle / 7
    p = figure(tools=TOOLS, plot_width=width, plot_height=height, title="",
        x_axis_type=None, y_axis_type=None,
        x_range=(-420, 420), y_range=(-420, 420),
        min_border=0, outline_line_color="black",
        background_fill_color="#f0e1d2", border_fill_color="#f0e1d2",
        toolbar_sticky=False)

    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None

    # annular wedges
    angles = np.pi/2 - big_angle/2 - np.arange(0, len(new_df.columns))*big_angle
    colors = ["#aeaeb8" for gram in new_df.columns]
    p.annular_wedge(
        0, 0, inner_radius, outer_radius, -big_angle+angles, angles, color=colors,
    )

    # small wedges
    max_vals = new_df.max()
    p.annular_wedge(0, 0, inner_radius, rad(new_df.loc[1], max_vals),
                    -big_angle+angles+5*small_angle, -big_angle+angles+6*small_angle,
                    color=region_color['Lisbon'])
    p.annular_wedge(0, 0, inner_radius, rad(new_df.loc[2], max_vals),
                    -big_angle+angles+3*small_angle, -big_angle+angles+4*small_angle,
                    color=region_color['Oporto'])
    p.annular_wedge(0, 0, inner_radius, rad(new_df.loc[3], max_vals),
                    -big_angle+angles+1*small_angle, -big_angle+angles+2*small_angle,
                    color=region_color['Other Region'])

    # circular axes and lables
    labels = np.power(10.0, np.arange(-3, 4))
    radii = a * np.sqrt(np.log(labels * 1E4)) + b
    p.circle(0, 0, radius=radii, fill_color=None, line_color="white")
    p.text(0, radii[2:], ['$'+str((1/r)*1000) for r in labels[2:]],
           text_font_size="8pt", text_align="center", text_baseline="middle")

    # radial axes
    p.annular_wedge(0, 0, inner_radius, outer_radius,
                    -big_angle+angles, -big_angle+angles, color="black")

    # product labels
    xr = radii[0]*np.cos(np.array(-big_angle/2 + angles))
    yr = radii[0]*np.sin(np.array(-big_angle/2 + angles))
    label_angle=np.array(-big_angle/2+angles)
    label_angle[label_angle < -np.pi/2] += np.pi # easier to read labels on the left side
    p.text(xr, yr, new_df.columns, angle=label_angle,
           text_font_size="9pt", text_align="center", text_baseline="middle")

    p.rect([-40, -40, -40], [18, 0, -18], width=30, height=13,
           color=list(region_color.values()))
    p.text([-15, -15, -15], [18, 0, -18], text=list(region_color),
           text_font_size="9pt", text_align="left", text_baseline="middle")
    return p

def scatter_plots(df, column1, column2, radius_column, take_log=False):
    if take_log:
        x = np.log(df[column1])
        y = np.log(df[column2])
        radii = np.log(df[radius_column])/(dwarf_constant*x.mean())
    else:
        x = df[column1]
        y = df[column2]
        radii = df[radius_column]/(dwarf_constant*x.mean())
    colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(x, y)]
    p = figure(tools=TOOLS, plot_width=width, plot_height=height, title=column1+" vs "+column2 +" scatter plot (radius of circles="+radius_column+")")
    p_s = p.scatter(x, y, radius=radii,
          fill_color=colors, fill_alpha=0.6, line_color=None)
    p.xaxis.axis_label = column1
    p.yaxis.axis_label = column2
    hover = HoverTool(tooltips=[
    ("index", "$index"),
    ("(x,y)", "($x, $y)"),
    ])
    p.add_tools(hover)    
    return p, p_s

def update(handle_number, df, x_value, y_value, size_value, take_log):
    if take_log:
        x = np.log(df[x_value])
        y = np.log(df[y_value])
        if size_value != 'None':
            radii = np.log(df[size_value])/(dwarf_constant*x.mean())
    else:
        x = df[column1]
        y = df[column2]
        if size_value != 'None':
            radii = df[radius_column]/(dwarf_constant*x.mean())
    p1_s.data_source.data['x'] = x
    p1_s.data_source.data['y'] = y
    if size_value != 'None':
        p1_s.data_source.data['radius'] = radii
    push_notebook(handle=handle_number)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4e470b17-e4d1-42b7-9509-c6528d7cc1af">Loading BokehJS ...</span>
#     </div>

# %%
p1 = circle_renderer(data1, "Region", "Channel")
p1_scatter, p1_s = scatter_plots(data1, "Milk", "Fresh", "Grocery", True)
layout = column([p1, p1_scatter])
t1 = show(layout, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7c109c39-e6d7-4ca0-8b39-4ee60c0fcdcf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("7c109c39-e6d7-4ca0-8b39-4ee60c0fcdcf");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7c109c39-e6d7-4ca0-8b39-4ee60c0fcdcf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7c109c39-e6d7-4ca0-8b39-4ee60c0fcdcf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9c558ebf-2f40-4360-8bf3-5c5c469d2a31":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9efd0c34-2db7-41cf-a570-b138d51a739b","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"687a27d9-35f9-4aba-b963-418144c17293","type":"CrosshairTool"},{"id":"df2eefdc-5920-4ce3-b0d8-7b8402c76df8","type":"PanTool"},{"id":"3df5322f-b6df-43da-89af-1af857f5e068","type":"WheelZoomTool"},{"id":"69ff7622-f4bb-4ebb-96b1-76213c102c3a","type":"ZoomInTool"},{"id":"02517555-3b87-4a49-ade4-83efcf299f36","type":"ZoomOutTool"},{"id":"4ba35a92-b0d4-4e97-bc1c-1694659a7a12","type":"BoxZoomTool"},{"id":"a82f4935-e004-4651-a02e-4c3d882b278a","type":"UndoTool"},{"id":"c4fe5317-2471-447c-ba70-7f9bada263fc","type":"RedoTool"},{"id":"7cb09495-a121-4eba-8222-05b06879c76c","type":"ResetTool"},{"id":"49f1fac8-26bc-44c8-8325-8618c04be175","type":"TapTool"},{"id":"a4d9ecb5-240c-4555-a6ac-63640673f659","type":"SaveTool"},{"id":"deeec8d7-7f9d-4bdc-b077-c7bfcae33470","type":"BoxSelectTool"},{"id":"26fe7c89-18bd-4f97-b82c-65c99a87a627","type":"PolySelectTool"},{"id":"5ab55886-2cbe-442a-a686-6c1c38879d91","type":"LassoSelectTool"}]},"id":"d517c048-cf26-493c-b59b-c928c56b0111","type":"Toolbar"},{"attributes":{"data_source":{"id":"c5c69907-3d24-41c8-a9f8-e3a3c0716ed5","type":"ColumnDataSource"},"glyph":{"id":"a2796b98-512e-45c8-806b-305102aa46ae","type":"AnnularWedge"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"068bf84b-8947-4f85-8ba9-b8100e66ac06","type":"AnnularWedge"},"selection_glyph":null,"view":{"id":"783dd6e0-c83f-4f8a-bd89-1fa3f571a5f8","type":"CDSView"}},"id":"8c44bf66-e759-4de7-b905-993747dd93bb","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"9d9ab0a3-ceb4-4ed7-b8f7-42dd08d3bfa5","type":"Title"},{"attributes":{"plot":{"id":"1ee887c6-d213-4851-a096-585e4b43c330","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad2955e4-b877-4a92-8d60-10bb3580fa05","type":"BasicTicker"}},"id":"6aa8f080-46d2-4be5-802a-a7b334886f03","type":"Grid"},{"attributes":{"fill_color":{"field":"fill_color"},"height":{"units":"data","value":13},"line_color":{"field":"line_color"},"width":{"units":"data","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"e7ef9e7a-87b1-4bba-bc0b-c149c39ac789","type":"Rect"},{"attributes":{"data_source":{"id":"dc11c518-cc85-4548-acd3-dc1d6bc60d0f","type":"ColumnDataSource"},"glyph":{"id":"8c939e64-b351-4122-8f99-9ca765eabed3","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"14c09985-9406-4a9a-bb3b-144739f6fbb0","type":"Text"},"selection_glyph":null,"view":{"id":"17ae00e5-cce1-4030-a1f8-f8ebd2096c0a","type":"CDSView"}},"id":"d4312980-31ca-42d1-be8d-b58026224ac9","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"480d3380-3613-4d05-b143-6ad6b6299eea","type":"ColumnDataSource"},"glyph":{"id":"e080379f-11e0-40ed-b667-8af656f2d151","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6dd01a67-2c88-4307-b897-faf6c6f3c1d4","type":"Circle"},"selection_glyph":null,"view":{"id":"7172ae79-f9cc-4c76-a092-4b7946a5cd69","type":"CDSView"}},"id":"74985dfc-7bc0-49ce-86c7-c6b3129351ce","type":"GlyphRenderer"},{"attributes":{},"id":"69ff7622-f4bb-4ebb-96b1-76213c102c3a","type":"ZoomInTool"},{"attributes":{"data_source":{"id":"c3ebddff-31a6-404b-bc60-385db888728a","type":"ColumnDataSource"},"glyph":{"id":"c1ea7e2a-6736-4f5e-a456-8a9cace5ea67","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0b9ea43d-afb9-4601-9d05-3db7c167811f","type":"Circle"},"selection_glyph":null,"view":{"id":"2fd08094-5d36-463b-b222-4f67bedec235","typ ...

# %%
interact(update, handle_number=fixed(t1), dataset=['Original', 'Drop NAs', 'Fill NA with 1', 'Fill NA with mean'], x_value=list(columns[2:].values), y_value=list(columns[2:].values), size_value=['None'] + list(columns[2:].values), take_log=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-7f2ad7452e89> in update(df, x_value, y_value, size_value, take_log)
#     125             radii = np.log(df[size_value])/(dwarf_constant*x.mean())
#     126     else:
# --> 127         x = df[column1]
#     128         y = df[column2]
#     129         if size_value != 'None':
#
# NameError: global name 'column1' is not defined

# %%
p2 = circle_renderer(data2, "Region", "Channel")
p2_scatter, p2_s = scatter_plots(data2, "Milk", "Fresh", "Grocery", True)
layout = column([p1, p1_scatter])
t1 = show(layout, notebook_handle=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-10c07c2f45b8> in <module>()
#       3 p2 = circle_renderer(data2, "Region", "Channel")
#       4 p2_scatter = scatter_plots(data2, "Milk", "Fresh", "Grocery", True)
# ----> 5 layout = column([p2, p2_scatter])
#       6 show(layout)
#
# C:\Anaconda2\lib\site-packages\bokeh\layouts.pyc in column(*args, **kwargs)
#     145             raise ValueError(
#     146                 """Only LayoutDOM items can be inserted into a column.
# --> 147                 Tried to insert: %s of type %s""" % (item, type(item))
#     148             )
#     149     return Column(children=col_children, sizing_mode=sizing_mode, **kwargs)
#
# ValueError: Only LayoutDOM items can be inserted into a column.
#                 Tried to insert: (Figure(id='4a0cd957-5860-4788-9df8-fe209abfb8a7', ...), GlyphRenderer(id='9a5af6d6-0908-421d-b7dc-156c109fadb5', ...)) of type <type 'tuple'>

# %%
p3 = circle_renderer(data3, "Region", "Channel")
p3_scatter = scatter_plots(data3, "Milk", "Fresh", "Grocery", True)
layout = column([p3, p3_scatter])
show(layout)

# %%
# approach 4: fill it with EM algorithm
show(layout)
